# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import logging

logging.basicConfig(filename='example.log', encoding='utf-8', level=logging.DEBUG)

# %%
logging.debug('this is debug msg')
logging.warning('this is warning msg')
logging.error('this is error msg')
logging.info('this is info msg')

# %%
levelname =  logging.getLevelName(level=logging.DEBUG)
# Out:
# logging.Logger

# %%
logging.basicConfig(format='%(levelname)s:%(message)s')

# %%
logging.debug('this is second debug msg')

# %%
logging.basicConfig(format='%(asctime)s %(message)s', datefmt='%m/%d/%Y %I:%M:%S %p')
logging.warning('is when this event was logged.')

# %%
logging.basicConfig(filename='example.log', encoding='utf-8', level=logging.DEBUG,
                    format='%()s %(message)s', datefmt='%m/%d/%Y %I:%M:%S %p')
logging.warning('is when this event was logged.')

# %%
 
logging.basicConfig(filename='example.log', level=logging.DEBUG ,format='%(levelname)s:%(message)s')
logger = logging.getLogger(__name__)
logger.warning('警告！')

# %%
import datetime
now = datetime.datetime.now()

# %%
from datetime import datetime


datetime.utcnow().strftime("%Y/%m/%d_%H:%M:%S")
# Out:
# '2022/11/21_07:13:10'

# %%
# %cd /content/drive/MyDrive/kaggle/single-cell-competition/notebooks
# %ls
# Out:
# /content/drive/MyDrive/kaggle/single-cell-competition/notebooks
#  all-in-one-catboost.ipynb
#  all-in-one-cat-single-model.ipynb
#  all-in-one-citeseq-multiome-with-keras.ipynb
#  all-in-one-lgbm.ipynb
#  all-in-one-multioutputreg-lgbm.ipynb
#  boot_strap_train.ipynb
#  create_submission.ipynb
#  eda.ipynb
#  example2.log
#  example.log
#  lb-t15-msci-multiome-catboostregressor.ipynb
#  multi-train.ipynb
#  __pycache__/
#  retrain-all-in-one-cat.ipynb
# 'Single-cell nb02.ipynb'
#  try_logging_nb.ipynb
#  try_logging.py

# %%
import time
from functools import wraps
from logging import (DEBUG, INFO, FileHandler, Formatter, StreamHandler,
                     getLogger)
from pathlib import Path

# from base_log import get_logger

## base_log.py
def create_logger(exp_version):
    log_file = Path(f"{exp_version}.log").resolve()

    # logger
    logger_ = getLogger(exp_version)
    logger_.setLevel(DEBUG)

    # formatter
    fmr = Formatter("[%(levelname)s] %(asctime)s >>\t%(message)s")

    # file handler
    fh = FileHandler(log_file)
    fh.setLevel(DEBUG)
    fh.setFormatter(fmr)

    # stream handler
    ch = StreamHandler()
    ch.setLevel(INFO)
    ch.setFormatter(fmr)

    logger_.addHandler(fh)
    logger_.addHandler(ch)


def get_logger(exp_version):
    return getLogger(exp_version)


## time_keeper.py
def stop_watch(VERSION):
    def _stop_watch(func):
        @wraps(func)
        def wrapper(*args, **kargs):
            start = time.time()

            result = func(*args, **kargs)

            elapsed_time = int(time.time() - start)
            minits, sec = divmod(elapsed_time, 60)
            hour, minits = divmod(minits, 60)

            get_logger(VERSION).info(
                "[elapsed_time]\t>> {:0>2}:{:0>2}:{:0>2}".format(
                    hour, minits, sec
                )
            )

        return wrapper

    return _stop_watch

# %%
## main.py
# from try_logging import create_logger, get_logger, stop_watch

VERSION = "zzzz" # 実験番号


@stop_watch(VERSION)
def function():
    time.sleep(5)
    print('hi')

create_logger(VERSION)
function()
params = {
    'leaf':4
}
get_logger('zzzz').info(params)
# Out:
# [INFO] 2022-11-21 08:04:10,428 >>	[elapsed_time]	>> 00:00:05
# INFO:zzzz:[elapsed_time]	>> 00:00:05
# [INFO] 2022-11-21 08:04:10,437 >>	{'leaf': 4}
# INFO:zzzz:{'leaf': 4}
# hi
